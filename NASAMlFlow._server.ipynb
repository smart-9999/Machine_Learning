# %%
import mlflow

# %%
import os
os.environ['MLFLOW_TRACKING_URI']='file:///C:/Users/LENOVO/Victor/'

# %%
import mlflow
all_runs = mlflow.search_runs(search_all_experiments =True)
print(all_runs)
# Out:
#                                run_id       experiment_id    status  \
# 0    4ddea7d6bf4a400f9fb1cac364606fca  569253254545706303  FINISHED
# 1    0723a3a2505943709b93b775955b819c  569253254545706303    FAILED
# 2    08faef42b32a454bb1e50f5e87cfd224  569253254545706303  FINISHED
# 3    0965ce3f8b1f40429bf2fdbe0ae93800  569253254545706303  FINISHED
# 4    a3e4041073884f0bba24f92cba56feef  569253254545706303  FINISHED
# ..                                ...                 ...       ...
# 117  2d9d07b90fca4b6685d8d4e5691fdb35  223275505784106486  FINISHED
# 118  e103cb0a709e4004af1278cf1bfc7006  223275505784106486  FINISHED
# 119  df8ddc13e3464932bf5c44f84dd76d6a  223275505784106486  FINISHED
# 120  c2460a0346ec4ed084529db4bd657264  223275505784106486  FINISHED
# 121  c0b4e16be7e54d0f9139bf18504c7e6f  223275505784106486  FINISHED
#
#                                           artifact_uri  \
# 0    file:///C:/Users/LENOVO/Victor/569253254545706...
# 1    file:///C:/Users/LENOVO/Victor/569253254545706...
# 2    file:///C:/Users/LENOVO/Victor/569253254545706...
# 3    file:///C:/Users/LENOVO/Victor/569253254545706...
# 4    file:///C:/Users/LENOVO/Victor/569253254545706...
# ..                                                 ...
# 117  file:///C:/Users/LENOVO/Victor/223275505784106...
# 118  file:///C:/Users/LENOVO/Victor/223275505784106...
# 119  file:///C:/Users/LENOVO/Victor/223275505784106...
# 120  file:///C:/Users/LENOVO/Victor/223275505784106...
# 121  file:///C:/Users/LENOVO/Victor/223275505784106...
#
#                           start_time                         end_time  \
# 0   2024-08-03 12:10:09.444000+00:00 2024-08-03 12:13:15.798000+00:00
# 1   2024-08-03 12:08:41.387000+00:00 2024-08-03 12:08:55.513000+00:00
# 2   2024-08-03 11:59:29.312000+00:00 2024-08-03 12:02:17.005000+00:00
# 3   2024-08-03 11:41:52.053000+00:00 2024-08-03 11:44:55.705000+00:00
# 4   2024-08-03 11:14:42.946000+00:00 2024-08-03 11:18:38.327000+00:00
# ..                               ...                              ...
# 117 2024-07-18 12:17:09.303000+00:00 2024-07-18 12:17:58.833000+00:00
# 118 2024-07-18 12:08:23.710000+00:00 2024-07-18 12:09:12.965000+00:00
# 119 2024-07-18 12:06:35.557000+00:00 2024-07-18 12:07:26.074000+00:00
# 120 2024-07-18 12:04:51.832000+00:00 2024-07-18 12:05:41.749000+00:00
# 121 2024-07-18 12:02:58.391000+00:00 2024-07-18 12:04:11.298000+00:00
#
#      metrics.rf_training_score  metrics.rf_testing_score  \
# 0                     1.000000                  0.995025
# 1                          NaN                       NaN
# 2                     1.000000                  0.995025
# 3                     1.000000                  0.995025
# 4                     1.000000                  0.995025
# ..                         ...                       ...
# 117                   0.801497                 -0.133019
# 118                   0.801503                 -0.127307
# 119                   0.802040                 -0.134495
# 120                   0.801937                 -0.128854
# 121                   0.801492                 -0.128328
#
#      metrics.gbm_training_score  metrics.logreg_testing_score  ...  \
# 0                      1.000000                      0.937456  ...
# 1                           NaN                           NaN  ...
# 2                      1.000000                      0.937456  ...
# 3                      1.000000                      0.937456  ...
# 4                      1.000000                      0.937456  ...
# ..                          ...                           ...  ...
# 117                    0.999997                           NaN  ...
# 118                    0.999997                           NaN  ...
# 119                    0.999997                           NaN  ...
# 120                    0.999997                           NaN  ...
# 121                    0.999997                           NaN  ...
#
#      params.lr_learning_rate  params.lr_minimum_samples_split  \
# 0                       None                             None
# 1                       None                             None
# 2                       None                             None
# 3                       None                             None
# 4                       None                             None
# ..                       ...                              ...
# 117                     None                             None
# 118                     None                             None
# 119                     None                             None
# 120                     None                             None
# 121                     None                             None
#
#      params.lr_max_depth  tags.feature_set_version  \
# 0                   None              loan default
# 1                   None                      None
# 2                   None              loan default
# 3                   None              loan default
# 4                   None              loan default
# ..                   ...                       ...
# 117                 None                      None
# 118                 None                      None
# 119                 None                      None
# 120                 None                      None
# 121                 None                      None
#
#                          tags.mlflow.log-model.history  tags.mlflow.user  \
# 0    [{"run_id": "4ddea7d6bf4a400f9fb1cac364606fca"...            LENOVO
# 1                                                 None            LENOVO
# 2    [{"run_id": "08faef42b32a454bb1e50f5e87cfd224"...            LENOVO
# 3    [{"run_id": "0965ce3f8b1f40429bf2fdbe0ae93800"...            LENOVO
# 4    [{"run_id": "a3e4041073884f0bba24f92cba56feef"...            LENOVO
# ..                                                 ...               ...
# 117  [{"run_id": "2d9d07b90fca4b6685d8d4e5691fdb35"...            LENOVO
# 118  [{"run_id": "e103cb0a709e4004af1278cf1bfc7006"...            LENOVO
# 119  [{"run_id": "df8ddc13e3464932bf5c44f84dd76d6a"...            LENOVO
# 120  [{"run_id": "c2460a0346ec4ed084529db4bd657264"...            LENOVO
# 121  [{"run_id": "c0b4e16be7e54d0f9139bf18504c7e6f"...            LENOVO
#
#      tags.mlflow.runName         tags.iteration_name  tags.mlflow.source.type  \
# 0     crawling-shark-933  test_rf_gbm_logreg_sklearn                    LOCAL
# 1      lyrical-skunk-937                        None                    LOCAL
# 2            fun-bat-260          test_rf_gb_sklearn                    LOCAL
# 3     thundering-bee-621          test_rf_gb_sklearn                    LOCAL
# 4      serious-grouse-71          test_rf_gb_sklearn                    LOCAL
# ..                   ...                         ...                      ...
# 117    exultant-frog-728                        None                    LOCAL
# 118   capricious-koi-124                        None                    LOCAL
# 119   honorable-shad-396                        None                    LOCAL
# 120   receptive-calf-891                        None                    LOCAL
# 121          fun-hog-667                        None                    LOCAL
#
#                                tags.mlflow.source.name
# 0    C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 1    C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 2    C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 3    C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 4    C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# ..                                                 ...
# 117  C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 118  C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 119  C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 120  C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 121  C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
#
# [122 rows x 71 columns]

# %%
# !mlflow models serve -p 8106 -m runs:/0965ce3f8b1f40429bf2fdbe0ae93800/random-forest-model --no-conda
