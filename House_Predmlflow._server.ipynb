# %%
import mlflow

# %%
import os
os.environ['MLFLOW_TRACKING_URI']='file:///C:/Users/LENOVO/Victor/'

# %%
import mlflow
all_runs = mlflow.search_runs(search_all_experiments =True)
print(all_runs)
# Out:
#                                run_id       experiment_id    status  \
# 0    999defb7f91a475aa9f0c7b8ce504ef3  208000453626339997  FINISHED
# 1    6ca03f7d79904c3686035984610a5204  208000453626339997  FINISHED
# 2    c8fafee4d9b748dfb652968c93683e69  208000453626339997  FINISHED
# 3    4ddea7d6bf4a400f9fb1cac364606fca  569253254545706303  FINISHED
# 4    0723a3a2505943709b93b775955b819c  569253254545706303    FAILED
# ..                                ...                 ...       ...
# 120  2d9d07b90fca4b6685d8d4e5691fdb35  223275505784106486  FINISHED
# 121  e103cb0a709e4004af1278cf1bfc7006  223275505784106486  FINISHED
# 122  df8ddc13e3464932bf5c44f84dd76d6a  223275505784106486  FINISHED
# 123  c2460a0346ec4ed084529db4bd657264  223275505784106486  FINISHED
# 124  c0b4e16be7e54d0f9139bf18504c7e6f  223275505784106486  FINISHED
#
#                                           artifact_uri  \
# 0    file:///C:/Users/LENOVO/Victor/208000453626339...
# 1    file:///C:/Users/LENOVO/Victor/208000453626339...
# 2    file:///C:/Users/LENOVO/Victor/208000453626339...
# 3    file:///C:/Users/LENOVO/Victor/569253254545706...
# 4    file:///C:/Users/LENOVO/Victor/569253254545706...
# ..                                                 ...
# 120  file:///C:/Users/LENOVO/Victor/223275505784106...
# 121  file:///C:/Users/LENOVO/Victor/223275505784106...
# 122  file:///C:/Users/LENOVO/Victor/223275505784106...
# 123  file:///C:/Users/LENOVO/Victor/223275505784106...
# 124  file:///C:/Users/LENOVO/Victor/223275505784106...
#
#                           start_time                         end_time  \
# 0   2024-08-03 12:41:47.998000+00:00 2024-08-03 12:44:00.343000+00:00
# 1   2024-08-03 12:31:27.564000+00:00 2024-08-03 12:36:18.522000+00:00
# 2   2024-08-03 12:23:26.885000+00:00 2024-08-03 12:25:47.737000+00:00
# 3   2024-08-03 12:10:09.444000+00:00 2024-08-03 12:13:15.798000+00:00
# 4   2024-08-03 12:08:41.387000+00:00 2024-08-03 12:08:55.513000+00:00
# ..                               ...                              ...
# 120 2024-07-18 12:17:09.303000+00:00 2024-07-18 12:17:58.833000+00:00
# 121 2024-07-18 12:08:23.710000+00:00 2024-07-18 12:09:12.965000+00:00
# 122 2024-07-18 12:06:35.557000+00:00 2024-07-18 12:07:26.074000+00:00
# 123 2024-07-18 12:04:51.832000+00:00 2024-07-18 12:05:41.749000+00:00
# 124 2024-07-18 12:02:58.391000+00:00 2024-07-18 12:04:11.298000+00:00
#
#      metrics.rf_testing_score  metrics.rf_training_score  \
# 0                    0.798204                   0.941660
# 1                    0.839079                   0.939072
# 2                    0.843704                   0.939288
# 3                    0.995025                   1.000000
# 4                         NaN                        NaN
# ..                        ...                        ...
# 120                 -0.133019                   0.801497
# 121                 -0.127307                   0.801503
# 122                 -0.134495                   0.802040
# 123                 -0.128854                   0.801937
# 124                 -0.128328                   0.801492
#
#      metrics.gbm_training_score  metrics.gbm_testing_score  ...  \
# 0                      0.999904                   0.894334  ...
# 1                      0.999918                   0.868305  ...
# 2                      0.999893                   0.888993  ...
# 3                      1.000000                   0.994314  ...
# 4                           NaN                        NaN  ...
# ..                          ...                        ...  ...
# 120                    0.999997                  -0.079123  ...
# 121                    0.999997                  -0.075715  ...
# 122                    0.999997                  -0.087836  ...
# 123                    0.999997                  -0.086914  ...
# 124                    0.999997                  -0.087440  ...
#
#      params.lr_minimum_samples_split  params.lr_learning_rate  \
# 0                               None                     None
# 1                               None                     None
# 2                               None                     None
# 3                               None                     None
# 4                               None                     None
# ..                               ...                      ...
# 120                             None                     None
# 121                             None                     None
# 122                             None                     None
# 123                             None                     None
# 124                             None                     None
#
#      params.lr_max_depth         tags.iteration_name  tags.mlflow.runName  \
# 0                   None          test_rf_gb_sklearn  inquisitive-elk-852
# 1                   None          test_rf_gb_sklearn    mercurial-kit-689
# 2                   None          test_rf_gb_sklearn      wistful-stoat-2
# 3                   None  test_rf_gbm_logreg_sklearn   crawling-shark-933
# 4                   None                        None    lyrical-skunk-937
# ..                   ...                         ...                  ...
# 120                 None                        None    exultant-frog-728
# 121                 None                        None   capricious-koi-124
# 122                 None                        None   honorable-shad-396
# 123                 None                        None   receptive-calf-891
# 124                 None                        None          fun-hog-667
#
#                          tags.mlflow.log-model.history  tags.mlflow.user  \
# 0    [{"run_id": "999defb7f91a475aa9f0c7b8ce504ef3"...            LENOVO
# 1    [{"run_id": "6ca03f7d79904c3686035984610a5204"...            LENOVO
# 2    [{"run_id": "c8fafee4d9b748dfb652968c93683e69"...            LENOVO
# 3    [{"run_id": "4ddea7d6bf4a400f9fb1cac364606fca"...            LENOVO
# 4                                                 None            LENOVO
# ..                                                 ...               ...
# 120  [{"run_id": "2d9d07b90fca4b6685d8d4e5691fdb35"...            LENOVO
# 121  [{"run_id": "e103cb0a709e4004af1278cf1bfc7006"...            LENOVO
# 122  [{"run_id": "df8ddc13e3464932bf5c44f84dd76d6a"...            LENOVO
# 123  [{"run_id": "c2460a0346ec4ed084529db4bd657264"...            LENOVO
# 124  [{"run_id": "c0b4e16be7e54d0f9139bf18504c7e6f"...            LENOVO
#
#                                tags.mlflow.source.name  \
# 0    C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 1    C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 2    C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 3    C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 4    C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# ..                                                 ...
# 120  C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 121  C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 122  C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 123  C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
# 124  C:\Users\LENOVO\anaconda3\Lib\site-packages\ip...
#
#      tags.feature_set_version  tags.mlflow.source.type
# 0                loan default                    LOCAL
# 1                loan default                    LOCAL
# 2                loan default                    LOCAL
# 3                loan default                    LOCAL
# 4                        None                    LOCAL
# ..                        ...                      ...
# 120                      None                    LOCAL
# 121                      None                    LOCAL
# 122                      None                    LOCAL
# 123                      None                    LOCAL
# 124                      None                    LOCAL
#
# [125 rows x 71 columns]

# %%
# !mlflow models serve -p 8105 -m runs:/e103cb0a709e4004af1278cf1bfc7006/gradient-boosting-model --no-conda
